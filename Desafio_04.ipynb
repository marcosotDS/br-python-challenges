# %% [markdown]
# <a href="https://colab.research.google.com/github/marcosotDS/br-python-challenges/blob/master/Desafio_04.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Desafio 4
#
# Escreva uma função cuja entrada é uma string e a saída é outra string com as palavras em ordem inversa.
#
# Exemplo:
#
# inverte_texto("Python é legal") ➞ "legal é Python"

# %%
def inverte_texto(texto):
  lista = texto.split()
  lista.reverse()
  texto_invertido = ' '.join(lista)
  print(texto_invertido)

# %%
inverte_texto('Python é legal')
# Out:
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# legal é Python
# ...
